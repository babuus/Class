# %%
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./Dataset/Bank_churn.csv')
print(df.shape)
df.head()
# Out:
# (10000, 14)
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df1 = df.drop('RowNumber', axis=1)
df1.drop('CustomerId', axis=1, inplace=True)
df1.drop('Surname', axis=1, inplace=True)
df1.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df2 = df1.copy()
columns_ = ['Geography', 'Gender']
le_dict = {col: LabelEncoder() for col in columns_ }
for col in columns_:
    df2[col] = le_dict[col].fit_transform(df1[col])
df2.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df2.hist(figsize=(15,13))
plt.show()

# %%
X = df2.drop('Exited',axis='columns')
y = df2['Exited']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8000, 10), (2000, 10), (8000,), (2000,))

# %%
cols_to_scale = ['CreditScore','Age', 'EstimatedSalary', 'Balance']
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])
# print(df2.columns)
df2.head()
# Out:
#    CreditScore  Geography  Gender       Age  Tenure   Balance  NumOfProducts  \
# 0        0.538          0       0  0.324324       2  0.000000              1
# 1        0.516          2       0  0.310811       1  0.334031              1
# 2        0.304          0       0  0.324324       8  0.636357              3
# 3        0.698          0       0  0.283784       1  0.000000              2
# 4        1.000          2       0  0.337838       2  0.500246              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1         0.506735       1
# 1          0               1         0.562709       0
# 2          1               0         0.569654       1
# 3          0               0         0.469120       0
# 4          1               1         0.395400       0

# %%
model = keras.Sequential()

#Input Layer
model.add(keras.layers.Dense(X.shape[1], activation='relu', input_shape = (10,)))

#Hidden Layer
# model.add(keras.layers.Dense(26, activation='relu'))
model.add(keras.layers.Dense(15, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

#Output Layer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#Tensorboard
log_dir = "logs/fit/bank_churn" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_28 (Dense)             (None, 15)                165
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 16
# =================================================================
# Total params: 291
# Trainable params: 291
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.fit(X_train, y_train, epochs=100, callbacks=[tensorboard_callback])
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 2ms/step - loss: 9.2866 - accuracy: 0.7064
# Epoch 2/100
# 250/250 [==============================] - 1s 2ms/step - loss: 7.5544 - accuracy: 0.7107
# Epoch 3/100
# 250/250 [==============================] - 1s 2ms/step - loss: 13.0906 - accuracy: 0.7036
# Epoch 4/100
# 250/250 [==============================] - 1s 2ms/step - loss: 9.3015 - accuracy: 0.6999
# Epoch 5/100
# 250/250 [==============================] - 0s 2ms/step - loss: 13.5305 - accuracy: 0.6905
# Epoch 6/100
# 250/250 [==============================] - 1s 2ms/step - loss: 9.4286 - accuracy: 0.7106
# Epoch 7/100
# 250/250 [==============================] - 1s 2ms/step - loss: 12.1842 - accuracy: 0.6991
# Epoch 8/100
# 250/250 [==============================] - 1s 2ms/step - loss: 9.3336 - accuracy: 0.7017
# Epoch 9/100
# 250/250 [==============================] - 1s 2ms/step - loss: 9.9627 - accuracy: 0.7053
# Epoch 10/100
# 250/250 [==============================] - 1s 2ms/step - loss: 10.5749 - accuracy: 0.7059
# Epoch 11/100
# 250/250 [==============================] - 1s 2ms/step - loss: 9.3642 - accuracy: 0.7080
# Epoch 12/100
# 250/250 [==============================] - 1s 2ms/step - loss: 11.3929 - accuracy: 0.6975
# Epoch 13/100
# 250/250 [==============================] - 1s 2ms/step - loss: 14.4717 - accuracy: 0.6877
# Epoch 14/100
# 250/250 [==============================] - 1s 2ms/step - loss: 8.8889 - accuracy: 0.7030
# Epoch 15/100
# 250/250 [==============================] - 1s 2ms/step - loss: 13.1054 - accuracy: 0.6992
# Epoch 16/100
# 250/250 [==============================] - 1s 2ms/step - loss: 10.0668 - accuracy: 0.6988
# Epoch 17/100
# 250/250 [==============================] - 0s 2ms/step - loss: 8.2948 - accuracy: 0.7122
# Epoch 18/100
# 250/250 [==============================] - 1s 2ms/step - loss: 13.1706 - accuracy: 0.6895
# Epoch 19/100
# 250/250 [==============================] - 0s 2ms/step - loss: 6.4043 - accuracy: 0.7190
# Epoch 20/100
# 250/250 [==============================] - 1s 2ms/step - loss: 6.2515 - accuracy: 0.7157
# Epoch 21/100
# 250/250 [==============================] - 0s 2ms/step - loss: 8.5885 - accuracy: 0.7085
# Epoch 22/100
# 250/250 [==============================] - 1s 2ms/step - loss: 10.3849 - accuracy: 0.7067
# Epoch 23/100
# 250/250 [==============================] - 1s 2ms/step - loss: 9.2999 - accuracy: 0.7071
# Epoch 24/100
# 250/250 [==============================] - 0s 2ms/step - loss: 7.8101 - accuracy: 0.7070
# Epoch 25/100
# 250/250 [==============================] - 0s 2ms/step - loss: 9.7192 - accuracy: 0.7036
# Epoch 26/100
# 250/250 [==============================] - 1s 2ms/step - loss: 6.9899 - accuracy: 0.7134
# Epoch 27/100
# 250/250 [==============================] - 1s 2ms/step - loss: 8.8657 - accuracy: 0.7003
# Epoch 28/100
# 250/250 [==============================] - 0s 2ms/step - loss: 6.2706 - accuracy: 0.7129
# Epoch 29/100
# 250/250 [==============================] - 0s 2ms/step - loss: 8.6669 - accuracy: 0.7040
# Epoch 30/100
# 250/250 [==============================] - 1s 2ms/step - loss: 6.0592 - accuracy: 0.7125
# Epoch 31/100
# 250/250 [==============================] - 0s 2ms/step - loss: 8.0417 - accuracy: 0.6975
# Epoch 32/100
# 250/250 [==============================] - 0s 2ms/step - loss: 8.9655 - accuracy: 0.7000
# Epoch 33/100
# 250/250 [==============================] - 1s 2ms/step - loss: 6.4109 - accuracy: 0.7129
# Epoch 34/100
# 250/250 [==============================] - 0s 2ms/step - loss: 7.0933 - accuracy: 0.7045
# Epoch 35/100
# 250/250 [==============================] - 0s 2ms/step - loss: 7.2603 - accuracy: 0.7139
# Epoch 36/100
# 250/250 [==============================] - 0s 2ms/step - loss: 9.5230 - accuracy: 0.7078
# Epoch 37/100
# 250/250 [==============================] - 1s 2ms/step - loss: 7.5209 - accuracy: 0.7089
# Epoch 38/100
# 250/250 [==============================] - 0s 2ms/step - loss: 9.7962 - accuracy: 0.7042
# Epoch 39/100
# 250/250 [==============================] - 0s 2ms/step - loss: 7.8750 - accuracy: 0.7020
# Epoch 40/100
# 250/250 [==============================] - 1s 2ms/step - loss: 6.9758 - accuracy: 0.7115
# Epoch 41/100
# 250/250 [==============================] - 0s 2ms/step - loss: 6.5160 - accuracy: 0.7048
# Epoch 42/100
# 250/250 [==============================] - 0s 2ms/step - loss: 10.1089 - accuracy: 0.7050
# Epoch 43/100
# 250/250 [==============================] - 0s 2ms/step - loss: 7.1012 - accuracy: 0.7059
# Epoch 44/100
# 250/250 [==============================] - 1s 2ms/step - loss: 7.1304 - accuracy: 0.7030
# Epoch 45/100
# 250/250 [==============================] - 0s 2ms/step - loss: 7.3565 - accuracy: 0.7078
# Epoch 46/100
# 250/250 [==============================] - 0s 2ms/step - loss: 7.8558 - accuracy: 0.7009
# Epoch 47/100
# 250/250 [==============================] - 0s 2ms/step - loss: 6.1096 - accuracy: 0.7094
# Epoch 48/100
# 250/250 [==============================] - 0s 2ms/step - loss: 5.1346 - accuracy: 0.7160
# Epoch 49/100
# 250/250 [==============================] - 0s 2ms/step - loss: 6.0866 - accuracy: 0.7088
# Epoch 50/100
# 250/250 [==============================] - 1s 2ms/step - loss: 7.7251 - accuracy: 0.7032
# Epoch 51/100
# 250/250 [==============================] - 0s 2ms/step - loss: 6.3004 - accuracy: 0.7103
# Epoch 52/100
# 250/250 [==============================] - 0s 2ms/step - loss: 9.2550 - accuracy: 0.7057
# Epoch 53/100
# 250/250 [==============================] - 1s 2ms/step - loss: 5.5227 - accuracy: 0.7115
# Epoch 54/100
# 250/250 [==============================] - 1s 2ms/step - loss: 6.3526 - accuracy: 0.7075
# Epoch 55/100
# 250/250 [==============================] - 1s 2ms/step - loss: 7.5034 - accuracy: 0.7011
# Epoch 56/100
# 250/250 [==============================] - 1s 2ms/step - loss: 5.7155 - accuracy: 0.7132
# Epoch 57/100
# 250/250 [==============================] - 1s 3ms/step - loss: 6.6162 - accuracy: 0.7075
# Epoch 58/100
# 250/250 [==============================] - 1s 2ms/step - loss: 7.5441 - accuracy: 0.7010
# Epoch 59/100
# 250/250 [==============================] - 1s 2ms/step - loss: 5.1502 - accuracy: 0.7178
# Epoch 60/100
# 250/250 [==============================] - 0s 2ms/step - loss: 5.8261 - accuracy: 0.7121
# Epoch 61/100
#  26/250 [==>...........................] - ETA: 0s - loss: 2.1564 - accuracy: 0.7560

# %%
model.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 27.6574 - accuracy: 0.7965
# [27.65740394592285, 0.796500027179718]

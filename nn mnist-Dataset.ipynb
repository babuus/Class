# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
len(X_train), len(X_test)
# Out:
# (60000, 10000)

# %%
print(X_train[0].shape,"Number is :", y_train[0])
plt.imshow(X_train[0])
plt.show()
# Out:
# (28, 28) Number is : 5

# %%
X_train = X_train/255
X_test = X_test/255

# %%
X_train_flt = X_train.reshape(len(X_train), 28*28)
X_test_flt = X_test.reshape(len(X_test), 28*28)
X_train_flt.shape, X_test_flt.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
model = keras.Sequential([
    keras.layers.Dense(10,input_shape=(784,),activation= 'sigmoid')
])
model.compile(
    optimizer='adam',
    loss = 'sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train_flt, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7184 - accuracy: 0.8151
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3117 - accuracy: 0.9120
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2859 - accuracy: 0.9189
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2706 - accuracy: 0.9241
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2655 - accuracy: 0.9270

# %%
model.evaluate(X_test_flt, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2691 - accuracy: 0.9258
# [0.2690596878528595, 0.9258000254631042]

# %%
prd = model.predict(X_test_flt)

# %%
plt.imshow(X_test[0]);

# %%
prd[0]
# Out:
# array([4.27942351e-02, 5.42372163e-07, 6.60675913e-02, 9.53752816e-01,
#        2.25286302e-03, 1.03191204e-01, 1.40374959e-06, 9.99816239e-01,
#        1.17071271e-01, 6.56076312e-01], dtype=float32)

# %%
np.argmax(prd[0])
# Out:
# 7

# %%
prd_lables = [np.argmax(i) for i in prd]
prd_lables[:9]
# Out:
# [7, 2, 1, 0, 4, 1, 4, 9, 6]

# %%
y_test[:9]
# Out:
# array([7, 2, 1, 0, 4, 1, 4, 9, 5], dtype=uint8)

# %%
cm = tf.math.confusion_matrix(labels=y_test, predictions=prd_lables)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 967,    0,    0,    2,    0,    4,    4,    1,    2,    0],
#        [   0, 1118,    3,    2,    0,    1,    4,    2,    5,    0],
#        [  11,   11,  924,   12,    6,    3,   12,   10,   38,    5],
#        [   5,    0,   21,  913,    1,   25,    4,    9,   24,    8],
#        [   3,    1,    5,    1,  910,    0,   10,    4,   10,   38],
#        [  13,    3,    2,   27,    8,  776,   18,    6,   31,    8],
#        [  14,    3,    5,    1,    7,   10,  914,    2,    2,    0],
#        [   2,    7,   22,    8,    8,    0,    0,  948,    1,   32],
#        [  13,   12,    6,   17,    9,   20,   10,   11,  870,    6],
#        [  12,    7,    1,    7,   26,    6,    0,   24,    8,  918]])>

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
model = keras.Sequential([
    keras.layers.Dense(100,input_shape=(784,),activation= 'relu'),
    keras.layers.Dense(10,activation= 'sigmoid')
])
model.compile(
    optimizer='adam',
    loss = 'sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train_flt, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4552 - accuracy: 0.8748
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1297 - accuracy: 0.9623
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0888 - accuracy: 0.9744
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0642 - accuracy: 0.9814
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0502 - accuracy: 0.9842

# %%
prd = model.predict(X_test_flt)
prd_lables = [np.argmax(i) for i in prd]
cm = tf.math.confusion_matrix(labels=y_test, predictions=prd_lables)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
er = ["categorical_crossentropy", "cosine_similarity", "mean_absolute_error", "mean_squared_error", "sparse_categorical_crossentropy"]
r = {}
for i in er:
    try:
        model = keras.Sequential([
            keras.layers.Flatten(input_shape=(28,28)),
            keras.layers.Dense(100,input_shape=(784,),activation= 'relu'),
            keras.layers.Dense(10,activation= 'sigmoid')
        ])
        model.compile(
            optimizer='adam',
            loss = i,
            metrics=['accuracy']
        )
        model.fit(X_train, y_train, epochs=5)
        r[i] = model.evaluate(X_test_flt, y_test)
    except Exception as e:
#         r[i] = e
        pass
# Out:
# Epoch 1/5
# Epoch 1/5
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 3.6468 - accuracy: 0.1155
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 3.5364 - accuracy: 0.1325
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 3.5771 - accuracy: 0.0938
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 3.5665 - accuracy: 0.0895
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 3.5530 - accuracy: 0.0669
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_17_input'), name='flatten_17_input', description="created by layer 'flatten_17_input'"), but it was called on an input with incompatible shape (None, 784).
# 313/313 [==============================] - 0s 1ms/step - loss: 3.5455 - accuracy: 0.0675
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 20.2850 - accuracy: 0.0905
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 20.2755 - accuracy: 0.1055
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 20.2236 - accuracy: 0.1035
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 20.1413 - accuracy: 0.1070
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 20.2713 - accuracy: 0.1036
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_18_input'), name='flatten_18_input', description="created by layer 'flatten_18_input'"), but it was called on an input with incompatible shape (None, 784).
# 313/313 [==============================] - 0s 1ms/step - loss: 20.2422 - accuracy: 0.1013
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4479 - accuracy: 0.8735
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1350 - accuracy: 0.9608
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0850 - accuracy: 0.9748
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0649 - accuracy: 0.9796
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0484 - accuracy: 0.9853
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_19_input'), name='flatten_19_input', description="created by layer 'flatten_19_input'"), but it was called on an input with incompatible shape (None, 784).
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0774 - accuracy: 0.9756

# %%
prd = model.predict(X_test_flt)
prd_lables = [np.argmax(i) for i in prd]
cm = tf.math.confusion_matrix(labels=y_test, predictions=prd_lables)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_6_input'), name='flatten_6_input', description="created by layer 'flatten_6_input'"), but it was called on an input with incompatible shape (None, 784).
# Text(69.0, 0.5, 'Truth')

# %%
r
# Out:
# {'mean_absolute_error': [3.54549503326416, 0.06750000268220901],
#  'mean_squared_error': [20.24220085144043, 0.10130000114440918],
#  'sparse_categorical_crossentropy': [0.07735822349786758, 0.975600004196167]}
